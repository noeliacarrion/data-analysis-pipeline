# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
data = pd.read_csv("./MissingMigrants-Global-2019-03-29T18-36-07.csv")

# %%
data
# Out:
#       Web ID Region of Incident      Reported Date  Reported Year  \
# 0      51591      Mediterranean     March 28, 2019           2019
# 1      51588      Mediterranean     March 26, 2019           2019
# 2      51589      Mediterranean     March 26, 2019           2019
# 3      51590      Mediterranean     March 26, 2019           2019
# 4      51587    Central America     March 25, 2019           2019
# 5      51580   US-Mexico Border     March 23, 2019           2019
# 6      51581   US-Mexico Border     March 23, 2019           2019
# 7      51585     Southeast Asia     March 23, 2019           2019
# 8      51586      Mediterranean     March 23, 2019           2019
# 9      51578   US-Mexico Border     March 21, 2019           2019
# 10     51579   US-Mexico Border     March 21, 2019           2019
# 11     51584    Central America     March 20, 2019           2019
# 12     51548      Mediterranean     March 19, 2019           2019
# ...

# %%
url = 'https://frontex.europa.eu/assets/Publications/Risk_Analysis/EaP_RAN/EaP-RAN__Q4_2017.pdf'

# %%
res_url = req.get(url)

# %%
res_url.content
# Out:
# b'%PDF-1.7\r%\xe2\xe3\xcf\xd3\r\n219 0 obj\r<</Linearized 1/L 779424/O 222/E 21553/N 16/T 778754/H [ 484 538]>>\rendobj\r             \r\n232 0 obj\r<</DecodeParms<</Columns 4/Predictor 12>>/Filter/FlateDecode/ID[<0BAB8D2391E65247A92DF2B2575A98BB><4E39B59340BCC544A59AB317ED5FE85A>]/Index[219 25]/Info 218 0 R/Length 74/Prev 778755/Root 220 0 R/Size 244/Type/XRef/W[1 2 1]>>stream\r\nh\xdebbd\x10``b`~\x07$\x187\x00\t\x06\x1d \xc1\x14\x00$XD@\xdc> !~\x16$\xf6\x16$\xe6\x01b\x85\x02\t\x89G@B\x10D\xac\xebe`bd\xc8\x06)f`$\x9a\xf8\xcf\xc8\xfa\x1d \xc0\x00\xe8\xd3\x0b\x19\r\nendstream\rendobj\rstartxref\r\n0\r\n%%EOF\r\n         \r\n243 0 obj\r<</Filter/FlateDecode/I 559/L 543/Length 449/S 446>>stream\r\nh\xdeb```f``:\xc0\xc0\xca\xc0\xc0\xfa\x82A\x84\x01\x01D\x80bl\x0c,\x0c\x1c\x16\r\x0c\t\x8c\x82M@\x95,\xd3>h_\x04J1\xe61\xa6KJ\xfb2\xd8&\x88\xfe`+h\xe0\xb9\xce\xa8\xf1@\xec?c\xd8\x01\xc1c\x0c\x01\x0f4\xd5\x85\x17r\xda\tO^\xa9\xe5\xe5\xc6\xc0\x90\xe1\xf3\xc5\xd7\xc2d\x8a\xc3f.\xb6\xe6;.\xcfnD\x9
# ...
